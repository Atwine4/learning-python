# %% [markdown]
# ## learning pandas methods
# - importing a csv file **pd.read_csv('file/path')**
# - calling out the first rows   **head()**
# - calling out the last rows    **tail()**
# - calling out a range of rows  **iloc[:]**
# - calling the dataframes summary of the percentiles, count, mean etc **describe()**
# - shows the specific characters in a column **unique()**
# - calling a specific character in a column **df[df['job']=='Data_analyst']**
# - other metnods **& , notna()**
# - sorting **sort_value() or sort_index()**
# - deleting a column **drop()**
# - grouping characters in a column **group_by()**
# - **agg(['mean', 'median', 'max'])**
# - **lambda X:**
# - other methods **isin() , any()**
# - ploting **plot(kind='barh')**
# - **plt.title('name title')**
# - **plt.ylabel('name ylable')**
# - **plt.xlabel('name xlable')**
# - **plt.xticks(rotation=45, ha = 'right')**
# - **plt.show()**

# %%
import pandas as pd

# %%
# importing a csv file
# use read_excel while importing an excel file
df = pd.read_csv('C:/Users/Ian/Desktop/panda ex/data_jobs1.csv')

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
# calling out the first rows 
# note: head() with out any specifies number in the brackets will only call out the 4 first rows of the data 
df.head(7)
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
# 5         Data Engineer                                  GCP Data Engineer
# 6  Senior Data Engineer                  Senior Data Engineer  - GCP Cloud
#
#                    job_location             job_via         job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby                 Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México                 Full-time
# 2               Berlin, Germany        via LinkedIn                 Full-time
# ...

# %%
# calling out the last rows
df.tail(4)
# Out:
#           job_title_short                                          job_title  \
# 785737       Data Analyst                                   CRM Data Analyst
# 785738   Business Analyst                     Commercial Analyst - Start Now
# 785739      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 785740  Software Engineer                                 AWS System Analyst
#
#                                job_location                    job_via  \
# 785737                   Bad Rodach, Jerman  melalui BeBee Deutschland
# 785738                             Malaysia           melalui Ricebowl
# 785739  Newark, New Jersey, Amerika Serikat        melalui Recruit.net
# 785740                                India             melalui Trigyn
#
#        job_schedule_type  job_work_from_home search_location  \
# 785737   Pekerjaan tetap               False         Germany
# 785738   Pekerjaan tetap               False        Malaysia
# ...

# %%
df.job_title_short.head(3)

df.job_title_short.tail(3)
# Out:
# 785738     Business Analyst
# 785739        Data Engineer
# 785740    Software Engineer
# Name: job_title_short, dtype: object

# %%
# getting them in a tabular form
df[['job_title_short']].head(4)
# Out:
#         job_title_short
# 0  Senior Data Engineer
# 1          Data Analyst
# 2         Data Engineer
# 3         Data Engineer

# %%
# calling out specific row numbers
df.iloc[100]
# Out:
# job_title_short                                             Data Scientist
# job_title                          Data Scientist, Risk Data Mining - USDS
# job_location                                             Mountain View, CA
# job_via                                                       via LinkedIn
# job_schedule_type                                                Full-time
# job_work_from_home                                                   False
# search_location                                  California, United States
# job_posted_date                                        2023-07-31 13:01:18
# job_no_degree_mention                                                False
# job_health_insurance                                                  True
# job_country                                                  United States
# salary_rate                                                           year
# ...

# %%
# calling out a range of rows
df.iloc[25:50]
# Out:
#           job_title_short                                          job_title  \
# 25    Senior Data Analyst                  Senior Officer, Data Analyst, GTO
# 26          Data Engineer                                      Data Engineer
# 27          Data Engineer  Principal Data Engineer (Lead), Knowledge Grap...
# 28         Data Scientist                                CRM Data Specialist
# 29         Data Scientist                                     Data Scientist
# 30   Senior Data Engineer     Senior Data Engineer (Work from home Eligible)
# 31           Data Analyst                           Stage - Data Analyst F/H
# 32         Data Scientist   Sr. Data Scientist (NLP) - Full-time / Part-time
# 33          Data Engineer                                      Data Engineer
# 34           Data Analyst  Data Analyst als Marketing Manager Automation ...
# 35          Data Engineer                        Data Engineer - Royal Canin
# ...

# %%
# calling out a range of rows and column.
# note iloc[range of rows, range of columns]

df.iloc[20:45,1:3]
# Out:
#                                             job_title  \
# 20                                     Data Scientist
# 21  Stage - data scientist – génération ia de donn...
# 22      Data Engineer / Développeur·euse Big Data F/H
# 23    PhD position in computer science (NLP, finance)
# 24                      Data Scientist (DataLab Team)
# 25                  Senior Officer, Data Analyst, GTO
# 26                                      Data Engineer
# 27  Principal Data Engineer (Lead), Knowledge Grap...
# 28                                CRM Data Specialist
# 29                                     Data Scientist
# 30     Senior Data Engineer (Work from home Eligible)
# 31                           Stage - Data Analyst F/H
# 32   Sr. Data Scientist (NLP) - Full-time / Part-time
# 33                                      Data Engineer
# 34  Data Analyst als Marketing Manager Automation ...
# 35                        Data Engineer - Royal Canin
# ...

# %%
# or the columns can also be called out like this

df[['job_title_short', 'job_location']].iloc[20:30]
# Out:
#               job_title_short                             job_location
# 20             Data Scientist                        Zaventem, Belgium
# 21             Data Scientist               Asnières-sur-Seine, France
# 22              Data Engineer                           Nantes, France
# 23  Machine Learning Engineer                                   Russia
# 24             Data Scientist                                 Anywhere
# 25        Senior Data Analyst                                Singapore
# 26              Data Engineer                            United States
# 27              Data Engineer                        San Francisco, CA
# 28             Data Scientist  San José Province, San José, Costa Rica
# 29             Data Scientist                 Pune, Maharashtra, India

# %%
# provides information about the table
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
# this give a summary of the percentiles, count, mean etc
df.describe()
# Out:
#        salary_year_avg  salary_hour_avg
# count     22003.000000     10662.000000
# mean     123286.274072        47.016598
# std       48312.449482        21.890738
# min       15000.000000         8.000000
# 25%       90000.000000        27.500000
# 50%      115000.000000        45.980000
# 75%      150000.000000        61.159996
# max      960000.000000       391.000000

# %%
# shows the specific characters in a column
df.job_title_short.unique()
# Out:
# array(['Senior Data Engineer', 'Data Analyst', 'Data Engineer',
#        'Business Analyst', 'Data Scientist', 'Machine Learning Engineer',
#        'Senior Data Analyst', 'Cloud Engineer', 'Senior Data Scientist',
#        'Software Engineer'], dtype=object)

# %%
# calling out data analyst positions in the job_title_short column

df[df.job_title_short=='Data Analyst']
# Out:
#        job_title_short                                          job_title  \
# 1         Data Analyst                                       Data Analyst
# 12        Data Analyst        Stagiaire Data Analyst (H/F) - Lyon (69006)
# 18        Data Analyst                                       Data Analyst
# 31        Data Analyst                           Stage - Data Analyst F/H
# 34        Data Analyst  Data Analyst als Marketing Manager Automation ...
# ...                ...                                                ...
# 785703    Data Analyst            Data Analyst - CRYPTOGRAPHY - Full-time
# 785705    Data Analyst          Expert Business Data Analyst - Now Hiring
# 785715    Data Analyst  Amul Careers 2023 - Apply Online - Data Analys...
# 785717    Data Analyst                 Data & Analytics Architect (w/m/x)
# 785737    Data Analyst                                   CRM Data Analyst
#
#                         job_location  \
# 1       Guadalajara, Jalisco, Mexico
# ...

# %%
# calling out the above analysts whose salary is > 10000

df[(df.job_title_short=='Data Analyst') & (df.salary_year_avg > 10000)]
# Out:
#        job_title_short                                    job_title  \
# 109       Data Analyst        Senior Supply Chain Analytics Analyst
# 180       Data Analyst                             Data Analyst III
# 410       Data Analyst  IT Business Lead Data Analyst - VP - Hybrid
# 988       Data Analyst                        DATA ANALYST (ONSITE)
# 1413      Data Analyst                          Junior BI Developer
# ...                ...                                          ...
# 784033    Data Analyst                     Recruitment Data Analyst
# 784423    Data Analyst                           Sales Data Analyst
# 784882    Data Analyst         Merchandising Analyst (Data Analyst)
# 785187    Data Analyst                                 Data Analyst
# 785515    Data Analyst                                 Data Analyst
#
#                        job_location                job_via job_schedule_type  \
# ...

# %%
# getting to show only values with out Nan


df[(df.job_title_short=='Data Analyst') & (df.salary_year_avg.notna())]
# Out:
#        job_title_short                                    job_title  \
# 109       Data Analyst        Senior Supply Chain Analytics Analyst
# 180       Data Analyst                             Data Analyst III
# 410       Data Analyst  IT Business Lead Data Analyst - VP - Hybrid
# 988       Data Analyst                        DATA ANALYST (ONSITE)
# 1413      Data Analyst                          Junior BI Developer
# ...                ...                                          ...
# 784033    Data Analyst                     Recruitment Data Analyst
# 784423    Data Analyst                           Sales Data Analyst
# 784882    Data Analyst         Merchandising Analyst (Data Analyst)
# 785187    Data Analyst                                 Data Analyst
# 785515    Data Analyst                                 Data Analyst
#
#                        job_location                job_via job_schedule_type  \
# ...

# %% [markdown]
# ##  Python data cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
type(df.job_posted_date[0])
# Out:
# str

# %%
# changing date type to datetime
df['job_posted_date'] = pd.to_datetime(df.job_posted_date)

# %%
# checking if the type for date has change to datetime
# it changed from object to datetime
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
type('job_posted_date')
# Out:
# str

# %%
# dt. can now provide opportunities to change date in to day, month, year etc 

df.job_posted_date.dt.month
# Out:
# 0          6
# 1          1
# 2         10
# 3          7
# 4          8
#           ..
# 785736     3
# 785737     3
# 785738     3
# 785739     3
# 785740     3
# Name: job_posted_date, Length: 785741, dtype: int32

# %%
# creating a new column for the month

df["job_posted_month"] = df.job_posted_date.dt.month

# %%
# job_posted_month the new column has been added into the table

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
# sorting data
# Inplace makes it permanently sorted or you can also use df = df.sort_values('job_posted_date')
# you can also use df = df.sort_values(by = 'job_posted_date') either way works

df.sort_values('job_posted_date', inplace = True)

# %%
df
# Out:
#                   job_title_short  \
# 108804               Data Analyst
# 96906                Data Analyst
# 98438                Data Analyst
# 110290               Data Analyst
# 72158         Senior Data Analyst
# ...                           ...
# 362129              Data Engineer
# 351830              Data Engineer
# 327439              Data Engineer
# 112373        Senior Data Analyst
# 90102   Machine Learning Engineer
#
#                                                 job_title  \
# 108804                                       Data Analyst
# 96906                                        Data Analyst
# 98438                                        Data Analyst
# 110290                                       Data Analyst
# 72158           Senior Data Analyst / Platform Experience
# ...                                                   ...
# 362129                                      Data engineer
# 351830                                      Data engineer
# ...

# %%
# removing a column
# label = mention the column name
# axis = (0 = rows, 1= columns) so this indictates what to drop, row or column

df.drop(labels ='salary_hour_avg', axis = 1, inplace=True)

# %%
# Column removed
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 785741 entries, 108804 to 90102
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  company_name           785723 non-null  object
# ...

# %%
# removing the null values

df.dropna(subset='salary_year_avg', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22003 entries, 108883 to 327439
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_title_short        22003 non-null  object
#  1   job_title              22003 non-null  object
#  2   job_location           21723 non-null  object
#  3   job_via                22003 non-null  object
#  4   job_schedule_type      21987 non-null  object
#  5   job_work_from_home     22003 non-null  bool
#  6   search_location        22003 non-null  object
#  7   job_posted_date        22003 non-null  datetime64[ns]
#  8   job_no_degree_mention  22003 non-null  bool
#  9   job_health_insurance   22003 non-null  bool
#  10  job_country            22003 non-null  object
#  11  salary_rate            22003 non-null  object
#  12  salary_year_avg        22003 non-null  float64
#  13  company_name           22003 non-null  object
# ...

# %% [markdown]
# ### Panda analysis

# %%
dn=pd.read_csv('C:/Users/Ian/Desktop/panda ex/data_jobs2.csv')

# %%
dn.describe()
# Out:
#        salary_year_avg  salary_hour_avg
# count     22003.000000     10662.000000
# mean     123286.274072        47.016598
# std       48312.449482        21.890738
# min       15000.000000         8.000000
# 25%       90000.000000        27.500000
# 50%      115000.000000        45.980000
# 75%      150000.000000        61.159996
# max      960000.000000       391.000000

# %%
# group by 
# eg groupby(['Animal']).mean() this groups the characters in a specified column
dn.groupby(['job_title_short'])['salary_year_avg'].median()
# Out:
# job_title_short
# Business Analyst              85000.0
# Cloud Engineer                90000.0
# Data Analyst                  90000.0
# Data Engineer                125000.0
# Data Scientist               127500.0
# Machine Learning Engineer    106415.0
# Senior Data Analyst          111175.0
# Senior Data Engineer         147500.0
# Senior Data Scientist        155500.0
# Software Engineer             99150.0
# Name: salary_year_avg, dtype: float64

# %%
# can also group more than one column
dn.groupby(['job_title_short', 'job_country'])['salary_year_avg'].median()
# Out:
# job_title_short    job_country
# Business Analyst   Afghanistan        NaN
#                    Albania            NaN
#                    Algeria            NaN
#                    Angola             NaN
#                    Argentina      71100.0
#                                    ...
# Software Engineer  Venezuela          NaN
#                    Vietnam        53600.0
#                    Yemen              NaN
#                    Zambia             NaN
#                    Zimbabwe           NaN
# Name: salary_year_avg, Length: 1387, dtype: float64

# %%
# remember when making more than one column the have to be in a list "[]"
dn.groupby(['job_title_short'])[['salary_year_avg', 'salary_hour_avg']].median()
# Out:
#                            salary_year_avg  salary_hour_avg
# job_title_short
# Business Analyst                   85000.0        40.362499
# Cloud Engineer                     90000.0        40.000000
# Data Analyst                       90000.0        32.615002
# Data Engineer                     125000.0        58.500000
# Data Scientist                    127500.0        47.500000
# Machine Learning Engineer         106415.0        47.535000
# Senior Data Analyst               111175.0        47.500000
# Senior Data Engineer              147500.0        61.500000
# Senior Data Scientist             155500.0        47.620003
# Software Engineer                  99150.0        47.560001

# %%
# you want more columns of min, max, median etc use "agg"
# note: if the characters are more one make it a list "[]""
dn.groupby(['job_title_short'])[['salary_year_avg']].agg(['min', 'max', 'median'])
# Out:
#                           salary_year_avg
#                                       min       max    median
# job_title_short
# Business Analyst                  16500.0  387460.0   85000.0
# Cloud Engineer                    42000.0  280000.0   90000.0
# Data Analyst                      25000.0  650000.0   90000.0
# Data Engineer                     15000.0  525000.0  125000.0
# Data Scientist                    27000.0  960000.0  127500.0
# Machine Learning Engineer         30000.0  325000.0  106415.0
# Senior Data Analyst               30000.0  425000.0  111175.0
# Senior Data Engineer              35000.0  425000.0  147500.0
# Senior Data Scientist             45000.0  890000.0  155500.0
# Software Engineer                 28000.0  375000.0   99150.0

# %%
dn.groupby(['job_title_short'])['salary_year_avg'].apply(lambda x: f'{x.min()} - {x.max()}')
# Out:
# job_title_short
# Business Analyst             16500.0 - 387460.0
# Cloud Engineer               42000.0 - 280000.0
# Data Analyst                 25000.0 - 650000.0
# Data Engineer                15000.0 - 525000.0
# Data Scientist               27000.0 - 960000.0
# Machine Learning Engineer    30000.0 - 325000.0
# Senior Data Analyst          30000.0 - 425000.0
# Senior Data Engineer         35000.0 - 425000.0
# Senior Data Scientist        45000.0 - 890000.0
# Software Engineer            28000.0 - 375000.0
# Name: salary_year_avg, dtype: object

# %%
dn['job_posted_date']=pd.to_datetime(dn['job_posted_date'])

# %%
dn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
dn.job_country.value_counts().head(20)
# Out:
# job_country
# United States     206292
# India              51088
# United Kingdom     40375
# France             39922
# Germany            27694
# Spain              25100
# Singapore          23696
# Sudan              21781
# Netherlands        20631
# Italy              17013
# Canada             16029
# Mexico             15139
# Poland             14793
# Portugal           14508
# Australia          12955
# South Africa       12414
# Belgium            12078
# Philippines        11786
# Ireland            11162
# Switzerland         9924
# Name: count, dtype: int64

# %%
dn.job_country.isin(["United States"]).any()
# Out:
# np.True_

# %%
us_jobs =dn[dn.job_country=="United States"]
us_jobs
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 3              Data Engineer
# 5              Data Engineer
# 6       Senior Data Engineer
# 9             Data Scientist
# ...                      ...
# 785673        Data Scientist
# 785685          Data Analyst
# 785692        Data Scientist
# 785703          Data Analyst
# 785705          Data Analyst
#
#                                                 job_title      job_location  \
# 0       Senior Clinical Data Engineer / Principal Clin...     Watertown, CT
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...   San Antonio, TX
# 5                                       GCP Data Engineer          Anywhere
# 6                       Senior Data Engineer  - GCP Cloud      Dearborn, MI
# 9                                       Data Scientist II          Anywhere
# ...                                                   ...               ...
# ...

# %%
us_jobs = us_jobs[us_jobs['salary_year_avg'].notna()]
us_jobs
# Out:
#        job_title_short                                          job_title  \
# 92       Data Engineer            Remote - Data Engineer - Permanent - W2
# 100     Data Scientist            Data Scientist, Risk Data Mining - USDS
# 109       Data Analyst              Senior Supply Chain Analytics Analyst
# 116     Data Scientist                                     Data Scientist
# 146      Data Engineer  Data Engineer Graduate (Real Time Communicatio...
# ...                ...                                                ...
# 785563  Data Scientist  Data Scientist I/II (Model Risk Management & M...
# 785624   Data Engineer                   Data Analytics Engineer (Hybrid)
# 785641   Data Engineer                                      Data Engineer
# 785648  Data Scientist  Director Data Scientist - Commercial Platforms...
# 785692  Data Scientist               Data Scientist- Hybrid Work Location
#
#              job_location                                    job_via  \
# ...

# %%
us_jobs.groupby(['job_title_short'])['salary_year_avg'].agg(['count','min','max','median']).sort_values('median', ascending = False)
# Out:
#                            count      min       max    median
# job_title_short
# Senior Data Scientist       1241  55000.0  475000.0  155000.0
# Machine Learning Engineer    128  44408.5  315000.0  150000.0
# Senior Data Engineer        1058  45000.0  375000.0  150000.0
# Data Scientist              4553  30000.0  960000.0  130000.0
# Software Engineer            157  48982.0  375000.0  130000.0
# Data Engineer               2915  23496.0  525000.0  125000.0
# Cloud Engineer                20  42000.0  221844.0  116100.0
# Senior Data Analyst          913  35360.0  425000.0  110000.0
# Business Analyst             431  35000.0  387460.0   90000.0
# Data Analyst                4350  25000.0  375000.0   90000.0

# %% [markdown]
# ### ploting charts in pandas

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
job_counts = dn.job_title_short.value_counts()
job_counts.plot(kind="line")
# Out:
# <Axes: xlabel='job_title_short'>

# %%
job_counts = dn.job_title_short.value_counts()
job_counts.plot(kind="bar")
plt.bar(job_counts.index, job_counts)
plt.title('Postings by job title')
plt.xlabel('')
plt.ylabel('count of job postings')
plt.xticks(rotation=45, ha = 'right')  # this was got from chatgpt. ha='right' means alignment of x lables to the right
plt.show()

# %%
dn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
dn['job_post_month']= dn.job_posted_date.dt.month
dn.sort_values('job_post_month', ascending=True, inplace=True)

job_salary = dn[dn['salary_year_avg'].notna()]
job_salary = job_salary.groupby(['job_post_month'])['salary_year_avg'].mean()
job_salary
# Out:
# job_post_month
# 1     123007.422072
# 2     122913.927237
# 3     122947.810047
# 4     121856.551050
# 5     123656.747729
# 6     124321.135360
# 7     123470.572994
# 8     125819.429100
# 9     125222.984594
# 10    124606.653605
# 11    119817.184014
# 12    120199.423414
# Name: salary_year_avg, dtype: float64

# %%
job_salary.plot(kind="line")
# Out:
# <Axes: xlabel='job_post_month'>

# %%
dn.plot(x='job_post_month', y='salary_year_avg', kind='line')
# Out:
# <Axes: xlabel='job_post_month'>

# %%
job_s = dn.groupby(['job_title_short'])['salary_year_avg'].median()
job_s = job_s.sort_values()
job_s.plot(kind='barh')
plt.title('salary scale by job title')
plt.ylabel('')
plt.xlabel('salary_year_avg')
plt.xticks(rotation=45, ha = 'right')
plt.show()
